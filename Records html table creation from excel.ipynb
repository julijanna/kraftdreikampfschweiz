# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# read excel sheets and remove these which are not relevant

sheets = xl.sheet_names
sheets = [k for k in sheets if 'WUAP' not in k and 'PL EQU' not in k and 'Tabelle1' not in k ]

# create dictionaries for categories, disciplines and gender

categories = ['Subjunior', 'Junior', 'Open', 'M1', 'M2', 'M3']
disciplines = ['Kniebeugen', 'Bankdrücken', 'Kreuzheben', 'Powerlifting Total', 'Single Lift Bankdrücken', 'Single Lift Kreuzheben',
              'Equipped - Single Lift Bankdrücken', 'RAW Bankdrücken']
gender = ['Man', 'Woman']

# %%
records_df = pd.DataFrame()

# read in data

for sheetname in sheets:
    if records_df.empty:
        records_df = pd.read_excel('Swiss_Powerlifting_Rekorde_2019.xlsx', sheet_name=sheetname)
    else:
        df = pd.read_excel('Swiss_Powerlifting_Rekorde_2019.xlsx', sheet_name=sheetname)
        records_df = records_df.append(df, sort=False)
        
# change column names for easier filtering later

records_df = records_df.rename(columns={'National-Rekorde \nRecords nationaux\nClassic\nKniebeugen / Squat': 'Kniebeugen',
                              'National-Rekorde \nRecords nationaux\nClassic\nBankdrücken / Développé couché': 'Bankdrücken',
                              'National-Rekorde \nRecords nationaux\nClassic\nKreuzheben / Soulevé de terre': 'Kreuzheben',
                              'National-Rekorde \nRecords nationaux\nClassic\nPowerlifting Total' : 'Powerlifting Total',
                              'National-Rekorde \nRecords nationaux\nClassic - Single Lift\nBankdrücken / Développé couché' : 'Single Lift Bankdrücken',
                              'National-Rekorde \nRecords nationaux\nClassic - Single Lift\nKreuzheben / Soulevé de terre' : 'Single Lift Kreuzheben',
                              'National-Rekorde \nRecords nationaux\nEquipped - Single Lift\nBankdrücken / Développé couché' : 'Equipped - Single Lift Bankdrücken',
                              'National-Rekorde \nRecords nationaux\nRAW\nBankdrücken / Développé couché' : 'RAW Bankdrücken'})
# Out:
# /Users/mkot/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
# fixing index

records_df = records_df.reset_index()
records_df = records_df.drop(['index'], axis=1)

# %%
records_df['Disziplin'] = pd.Series()
records_df['Gewicht'] = pd.Series()

# mapping column names to disciplines and values from multiple columns to weight
# it creates sql-like table which can be grouped and sorted

for i in disciplines:
    records_df['Disziplin'].loc[~records_df[i].isnull()] = records_df[i].name
    for index, value in records_df[i].items():
        if str(value) != 'nan':
            records_df['Gewicht'].iloc[index] = value

records_df = records_df[records_df.columns.drop(list(disciplines))]
records_df.columns = ['Klasse', 'Athlet', 'Rekord', 'Datum', 'Wettkampf', 'Ort', 'Land', 'Disziplin', 'Gewicht']
# Out:
# /Users/mkot/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
records_df['Geschlecht'] = pd.Series()
records_df['Kategorie'] = pd.Series()

current_gender = ''
current_category = ''

# mapping gender and category rows to column values

for index, value in records_df['Klasse'].items():
    if value in gender:
        current_gender = value
    elif value in categories:
        current_category = value
        
    records_df['Geschlecht'].iloc[index] = current_gender
    records_df['Kategorie'].iloc[index] = current_category

# %%
# reducing the number of columns and reordering them

records_df = records_df[(records_df.Gewicht != 'Gewicht') & (records_df.Gewicht != 'Record') & (~records_df.Gewicht.isna())]
records_df = records_df.reset_index()
records_df = records_df.drop(['index'], axis=1)
records_df = records_df[['Kategorie', 'Disziplin', 'Geschlecht', 'Klasse', 'Athlet', 'Gewicht', 'Rekord', 'Datum', 'Wettkampf', 'Ort', 'Land']]

# %%
# fill NaNs with empty strings

records_df.fillna('', inplace=True)

# %%
# create special values for sorting

records_df['sort_order_kategorie'] = pd.Series()
records_df['sort_order_geschlecht'] = pd.Series()
records_df['sort_order_disziplin'] = pd.Series()

for index, row in records_df.iterrows():
    if row['Kategorie'] == 'Open':
        records_df.loc[index, 'sort_order_kategorie'] = 0
    elif row['Kategorie'] == 'Subjunior':
        records_df.loc[index, 'sort_order_kategorie'] = 1
    elif row['Kategorie'] == 'Junior':
        records_df.loc[index, 'sort_order_kategorie'] = 2
    elif row['Kategorie'] == 'M1':
        records_df.loc[index, 'sort_order_kategorie'] = 3
    elif row['Kategorie'] == 'M2':
        records_df.loc[index, 'sort_order_kategorie'] = 4
    elif row['Kategorie'] == 'M3':
        records_df.loc[index, 'sort_order_kategorie'] = 5
    
    if row['Geschlecht'] == 'Woman':
        records_df.loc[index, 'sort_order_geschlecht'] = 0
    else:
        records_df.loc[index, 'sort_order_geschlecht'] = 1
        
    if row['Disziplin'] == 'Kniebeugen':
        records_df.loc[index, 'sort_order_disziplin'] = 0
    elif row['Disziplin'] == 'Bankdrücken':
        records_df.loc[index, 'sort_order_disziplin'] = 1
    elif row['Disziplin'] == 'Kreuzheben':
        records_df.loc[index, 'sort_order_disziplin'] = 2
    elif row['Disziplin'] == 'Powerlifting Total':
        records_df.loc[index, 'sort_order_disziplin'] = 3
    elif row['Disziplin'] == 'Single Lift Bankdrücken':
        records_df.loc[index, 'sort_order_disziplin'] = 4
    elif row['Disziplin'] == 'Single Lift Kreuzheben':
        records_df.loc[index, 'sort_order_disziplin'] = 5
    elif row['Disziplin'] == 'Equipped - Single Lift Bankdrücken':
        records_df.loc[index, 'sort_order_disziplin'] = 6
    elif row['Disziplin'] == 'RAW Bankdrücken':
        records_df.loc[index, 'sort_order_disziplin'] = 7
        
# sort dataframe and remove special columns
        
records_df.sort_values(by = ['sort_order_kategorie', 'sort_order_disziplin', 'sort_order_geschlecht', 'Klasse'], inplace=True)
records_df = records_df.drop(['sort_order_kategorie', 'sort_order_geschlecht', 'sort_order_disziplin'], axis=1)

# %%
records_df
# Out:
#     Kategorie                           Disziplin Geschlecht Klasse  \
# 38       Open                          Kniebeugen      Woman     47
# 39       Open                          Kniebeugen      Woman     52
# 40       Open                          Kniebeugen      Woman     57
# 41       Open                          Kniebeugen      Woman     63
# 42       Open                          Kniebeugen      Woman     72
# 43       Open                          Kniebeugen      Woman     84
# 44       Open                          Kniebeugen      Woman    84+
# 30       Open                          Kniebeugen        Man     59
# 31       Open                          Kniebeugen        Man     66
# 32       Open                          Kniebeugen        Man     74
# 33       Open                          Kniebeugen        Man     83
# 34       Open                          Kniebeugen        Man     93
# 35       Open                          Kniebeugen        Man    105
# 36       Open                          Kniebeugen        Man    120
# 37       Open                          Kniebeugen        Man   120+
# 128      Open                         Bankdrücken      Woman     47
# 129      Open                         Bankdrücken      Woman     52
# 130      Open                         Bankdrücken      Woman     57
# 131      Open                         Bankdrücken      Woman     63
# 132      Open                         Bankdrücken      Woman     72
# 133      Open                         Bankdrücken      Woman     84
# 134      Open                         Bankdrücken      Woman    84+
# 120      Open                         Bankdrücken        Man     59
# 121      Open                         Bankdrücken        Man     66
# 122      Open                         Bankdrücken        Man     74
# 123      Open                         Bankdrücken        Man     83
# 124      Open                         Bankdrücken        Man     93
# 125      Open                         Bankdrücken        Man    105
# 126      Open                         Bankdrücken        Man    120
# 127      Open                         Bankdrücken        Man   120+
# ..        ...                                 ...        ...    ...
# 644        M3              Single Lift Kreuzheben        Man     66
# 645        M3              Single Lift Kreuzheben        Man     74
# 646        M3              Single Lift Kreuzheben        Man     83
# 647        M3              Single Lift Kreuzheben        Man     93
# 648        M3              Single Lift Kreuzheben        Man    105
# 649        M3              Single Lift Kreuzheben        Man    120
# 650        M3              Single Lift Kreuzheben        Man   120+
# 532        M3  Equipped - Single Lift Bankdrücken      Woman     47
# 533        M3  Equipped - Single Lift Bankdrücken      Woman     52
# 534        M3  Equipped - Single Lift Bankdrücken      Woman     57
# 535        M3  Equipped - Single Lift Bankdrücken      Woman     63
# 536        M3  Equipped - Single Lift Bankdrücken      Woman     72
# 537        M3  Equipped - Single Lift Bankdrücken      Woman     84
# 538        M3  Equipped - Single Lift Bankdrücken      Woman    84+
# 524        M3  Equipped - Single Lift Bankdrücken        Man     59
# 525        M3  Equipped - Single Lift Bankdrücken        Man     66
# 526        M3  Equipped - Single Lift Bankdrücken        Man     74
# 527        M3  Equipped - Single Lift Bankdrücken        Man     83
# 528        M3  Equipped - Single Lift Bankdrücken        Man     93
# 529        M3  Equipped - Single Lift Bankdrücken        Man    105
# 530        M3  Equipped - Single Lift Bankdrücken        Man    120
# 531        M3  Equipped - Single Lift Bankdrücken        Man   120+
# 546        M3                     RAW Bankdrücken      Woman  -67.5
# 543        M3                     RAW Bankdrücken        Man   -100
# 544        M3                     RAW Bankdrücken        Man   -110
# 545        M3                     RAW Bankdrücken        Man   -125
# 540        M3                     RAW Bankdrücken        Man    -60
# 539        M3                     RAW Bankdrücken        Man    -75
# 541        M3                     RAW Bankdrücken        Man  -82.5
# 542        M3                     RAW Bankdrücken        Man    -90
#
#                     Athlet  Gewicht Rekord Datum       Wettkampf          Ort  \
# 38           Sirman Coline     92.5     SR  2017             WEC    Luxemburg
# 39            Keusch Katja       90     SR  2019              SM      Vilters
# 40              Henzi Anna      120     SR  2019              SM      Vilters
# 41            Kamberi Jana    147.5     SR  2019              SM      Vilters
# 42            Jonasch Anna      155     SR  2019              SM      Vilters
# 43          Butera Jessica    167.5     SR  2019              SM      Vilters
# 44          Butera Jessica      170     SR  2019             DSM       Zürich
# 30          Swiss standard      140
# 31              Jost Alain      190     SR  2019              EM       Kaunas
# 32            Sigrist Sven      210     SR  2018              WM      Calgary
# 33         Prizeman Edmund      255     SR  2019              SM      Vilters
# 34          Herrsche Dario      265     SR  2019             DSM       Zürich
# 35            Meier Steven      285     SR  2019              SM      Vilters
# 36           Pauli Daniele      275     SR  2017             DSM         Bern
# 37           Jäggi Patrick      310     SR  2019              SM      Vilters
# 128          Sirman Coline     62.5     SR  2017              WM        Minsk
# 129         Swiss standard       65
# 130             Henzi Anna       81     SR  2019              SM      Vilters
# 131  Weizenegger Claire F.       83     SR  2019              SM      Vilters
# 132            Marx Andrea       90     SR  2019              EM       Kaunas
# 133         Butera Jessica     87.5     SR  2019              SM      Vilters
# 134         Swiss standard       95
# 120         Swiss standard       90
# 121             Jost Alain    137.5     SR  2019    Länder Pokal   Kennelbach
# 122        Solfrini Sascha      140     SR  2019        Quali SM    Landquart
# 123        Prizeman Edmund    170.5     SR  2019              SM      Vilters
# 124         Herrsche Dario      175     SR  2019             DSM       Zürich
# 125          Pauli Daniele      185     SR  2018              EM       Kaunas
# 126         Swiss standard      180
# 127         Swiss standard      200
# ..                     ...      ...    ...   ...             ...          ...
# 644         Swiss standard      110
# 645         Swiss standard      120
# 646         Swiss standard      130
# 647         Swiss standard      140
# 648         Swiss standard      150
# 649         Swiss standard      160
# 650         Swiss standard      170
# 532         Swiss standard       50
# 533         Swiss standard       55
# 534         Swiss standard       60
# 535         Swiss standard       65
# 536         Swiss standard       75
# 537         Swiss standard       80
# 538         Swiss standard       90
# 524         Swiss standard      100
# 525         Swiss standard      110
# 526         Swiss standard      120
# 527         Swiss standard      130
# 528         Swiss standard      140
# 529      Aymon Jean-Pierre      175     SR  2015              SR       Sierre
# 530         Swiss standard      160
# 531         Swiss standard      170
# 546          Aerni Pauline     1073     SR  2018  TM Bankdrücken       Sierre
# 543          Heiden Tobias   2557.5     SR  2003           DMS I  Ernetschwil
# 544           Urech Marcel     3605     SR  2003           DMS I  Ernetschwil
# 545          Hoyer Andreas     2460     SR  2003           DMS I  Ernetschwil
# 540             Heid Roger     1650     SR  2003         SM 2003    Wettingen
# 539           Aymon Jérôme     2600     SR  2016  TM Bankdrücken       Sierre
# 541         Brunner Andres  2096.25     SR  2003           DMS I  Ernetschwil
# 542             Gut Stefan   2497.5     SR  2003           DMS I  Ernetschwil
#
#     Land
# 38   LUX
# 39   SUI
# 40   SUI
# 41   SUI
# 42   SUI
# 43   SUI
# 44   SUI
# 30
# 31   LTU
# 32   CAN
# 33   SUI
# 34   SUI
# 35   SUI
# 36   SUI
# 37   SUI
# 128  BLR
# 129
# 130  SUI
# 131  SUI
# 132  LTU
# 133  SUI
# 134
# 120
# 121  AUT
# 122  SUI
# 123  SUI
# 124  SUI
# 125  LTU
# 126
# 127
# ..   ...
# 644
# 645
# 646
# 647
# 648
# 649
# 650
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 524
# 525
# 526
# 527
# 528
# 529  SUI
# 530
# 531
# 546  SUI
# 543  SUI
# 544  SUI
# 545  SUI
# 540  SUI
# 539  SUI
# 541  SUI
# 542  SUI
#
# [658 rows x 11 columns]

# %%
records_df.to_html(index=False, buf='records.html')
